# %% [markdown]
# # Tutorial for Dynamic Obstacle Avoidance
# *** This tutorial is based on the publication:
# Huber, Lukas, Aude Billard, and Jean-Jacques E. Slotine. "Avoidance of Convex and Concave Obstacles with Convergence ensured through Contraction." IEEE Robotics and Automation Letters (2019).***
#
# $$\dot \xi = M(\xi) f(\xi)$$

# %%
# General classes
import numpy as np
from numpy import pi

# TODO remove this
import sys
sys.path.append('/home/lukas/Code/ObstacleAvoidance/dynamic_obstacle_avoidance_linear/python/src/')
sys.path.append('/home/lukas/Code/ObstacleAvoidance/dynamic_obstacle_avoidance_linear/python/script/')

# %%
# Custom classes
from dynamic_obstacle_avoidance.obstacle_avoidance.obstacle import Obstacle
from dynamic_obstacle_avoidance.visualization.vector_field_visualization import Simulation_vectorFields

# %%
obstacles = []

a=[1, 1]
p=[1,1]
x0=[1.5,0]
th_r=0/180*pi
sf=1
vel = [0, 0]
obstacles.append(Obstacle(a=a, p=p, x0=x0,th_r=th_r, sf=sf, xd=vel))

# %%
Simulation_vectorFields(obs=obstacles, xAttractor=[0,0],
                        x_range=[-5,5], y_range=[-2,2], point_grid=100, noTicks=False)
# Out:
# Modulation calulcation total: 4.0 s
# Average time: 0.0 ms
# /home/lukas/Code/ObstacleAvoidance/dynamic_obstacle_avoidance_linear/python/src/dynamic_obstacle_avoidance/visualization/vector_field_visualization.py:105: RuntimeWarning: invalid value encountered in true_divide
#   dx1_noColl, dx2_noColl = dx1_noColl/normVel, dx2_noColl/normVel
